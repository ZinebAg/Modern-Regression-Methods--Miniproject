# %% [markdown]
# # GAM Analysis of models

# %% [markdown]
# ### Load fitted models and run GAM_utils.R

# %%
setwd("~/GitHub/MRM_mini_project")
source('GAM_utils.R')
# loaded saved fitted models
load("C:/Users/lacko/OneDrive - epfl.ch/Modern Regression Methods/Project/models_full_dataset.RData")
load("C:/Users/lacko/OneDrive - epfl.ch/Modern Regression Methods/Project/gam_qp_tr_and_val.RData")
# Out:
# Warning message:
# "package 'dplyr' was built under R version 3.6.3"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"Warning message:
# "package 'purrr' was built under R version 3.6.3"Warning message:
# "package 'tidyr' was built under R version 3.6.3"Warning message:
# "package 'cowplot' was built under R version 3.6.3"Warning message:
# "package 'mgcv' was built under R version 3.6.3"Loading required package: nlme
#
# Attaching package: 'nlme'
#
# The following object is masked from 'package:dplyr':
#
#     collapse
#
# This is mgcv 1.8-35. For overview type 'help("mgcv-package")'.
# Warning message:
# "package 'MASS' was built under R version 3.6.3"
# Attaching package: 'MASS'
#
# The following object is masked from 'package:dplyr':
#
#     select
#
# Warning message:
# "package 'Metrics' was built under R version 3.6.3"Warning message:
# "package 'tidymv' was built under R version 3.6.3"

# %% [markdown]
# ## Poisson GAM

# %%
diagnostics.gam(gam.poiss, df_val, 'poiss')
# Out:
# [1] "AIC:"
# [1] 1681923
#
# Family: poisson
# Link function: log
#
# Formula:
# CNT ~ 1 + s(lat, lon, bs = "sos") + s(year, k = 5) + s(month,
#     k = 3) + s(altiMean) + s(altiSD) + s(temperature) + s(dew_temperature) +
#     s(potential_evaporation) + s(evaporation) + s(solar_radiation) +
#     s(thermal_radiation) + s(precipitation) + s(humidity) + s(Wspeed) +
#     ti(temperature, precipitation) + ti(temperature, solar_radiation) +
#     ti(temperature, thermal_radiation) + ti(temperature, Wspeed) +
#     ti(evaporation, precipitation) + ti(potential_evaporation,
#     precipitation) + s(lc_Cropland) + s(lc_Vegetation_Bare_areas) +
#     s(lc_Tree_broadleaved_evergreen) + s(lc_Tree_broadleaved_deciduous) +
#     s(lc_Tree_needleleave_evergreen) + s(lc_Tree_needleleave_deciduous) +
#     s(lc_Tree_mixed) + s(lc_Grassland) + s(lc_Shrubs) + s(lc_Urban) +
#     s(lc_Water_and_flooded_areas) + ti(lc_Tree_broadleaved_deciduous,
#     month) + ti(lc_Tree_needleleave_deciduous, month) + ti(lc_Tree_broadleaved_evergreen,
#     lc_Shrubs) + ti(lc_Tree_broadleaved_deciduous, lc_Shrubs) +
#     ti(lc_Tree_needleleave_evergreen, lc_Shrubs) + ti(lc_Tree_needleleave_deciduous,
#     lc_Shrubs) + ti(lc_Tree_mixed, lc_Shrubs) + ti(lc_Tree_broadleaved_evergreen,
#     lc_Grassland) + ti(lc_Tree_broadleaved_deciduous, lc_Grassland) +
#     ti(lc_Tree_needleleave_evergreen, lc_Grassland) + ti(lc_Tree_needleleave_deciduous,
#     lc_Grassland) + ti(lc_Tree_mixed, lc_Grassland) + ti(lc_Tree_broadleaved_evergreen,
#     lc_Urban) + ti(lc_Tree_broadleaved_deciduous, lc_Urban) +
#     ti(lc_Tree_needleleave_evergreen, lc_Urban) + ti(lc_Tree_needleleave_deciduous,
#     lc_Urban) + ti(lc_Tree_mixed, lc_Urban) + ti(lc_Shrubs, lc_Urban) +
#     ti(lc_Grassland, lc_Urban) + ti(lc_Shrubs, solar_radiation) +
#     ti(lc_Shrubs, thermal_radiation) + ti(lc_Shrubs, temperature) +
#     ti(lc_Grassland, solar_radiation) + ti(lc_Grassland, thermal_radiation) +
#     ti(lc_Grassland, temperature)
#
# Parametric coefficients:
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)  1114.80      28.41   39.24   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Approximate significance of smooth terms:
#                                                   edf Ref.df    Chi.sq p-value
# s(lat,lon)                                     48.968 49.000 105518.62  <2e-16
# s(year)                                         3.981  4.000   2962.90  <2e-16
# s(month)                                        1.997  2.000    596.85  <2e-16
# s(altiMean)                                     8.943  8.999   3045.13  <2e-16
# s(altiSD)                                       8.980  9.000   3172.50  <2e-16
# s(temperature)                                  8.964  8.994   1688.74  <2e-16
# s(dew_temperature)                              8.930  8.996   3445.31  <2e-16
# s(potential_evaporation)                        7.357  7.829    668.26  <2e-16
# s(evaporation)                                  8.924  8.985    909.44  <2e-16
# s(solar_radiation)                              8.953  8.998   1113.74  <2e-16
# s(thermal_radiation)                            8.874  8.946    572.04  <2e-16
# s(precipitation)                                6.201  6.869     95.53  <2e-16
# s(humidity)                                     8.930  8.997  10222.08  <2e-16
# s(Wspeed)                                       8.176  8.552    216.18  <2e-16
# ti(temperature,precipitation)                  13.180 13.693   5797.53  <2e-16
# ti(temperature,solar_radiation)                15.949 15.998   2383.90  <2e-16
# ti(temperature,thermal_radiation)              14.629 15.011   1970.73  <2e-16
# ti(temperature,Wspeed)                         15.780 15.930   1861.82  <2e-16
# ti(evaporation,precipitation)                  12.465 13.415    912.10  <2e-16
# ti(potential_evaporation,precipitation)        13.692 14.162   1485.53  <2e-16
# s(lc_Cropland)                                  8.970  9.000   8449.13  <2e-16
# s(lc_Vegetation_Bare_areas)                     8.898  8.991   3950.64  <2e-16
# s(lc_Tree_broadleaved_evergreen)                8.974  9.000   1642.06  <2e-16
# s(lc_Tree_broadleaved_deciduous)                7.030  7.075    779.36  <2e-16
# s(lc_Tree_needleleave_evergreen)                8.495  8.855   1546.89  <2e-16
# s(lc_Tree_needleleave_deciduous)                8.777  8.978    521.48  <2e-16
# s(lc_Tree_mixed)                                8.582  8.865   1372.58  <2e-16
# s(lc_Grassland)                                 8.984  9.000   3939.91  <2e-16
# s(lc_Shrubs)                                    8.966  8.999   2911.04  <2e-16
# s(lc_Urban)                                     8.997  9.000  11152.79  <2e-16
# s(lc_Water_and_flooded_areas)                   8.965  8.999   6847.08  <2e-16
# ti(lc_Tree_broadleaved_deciduous,month)        14.460 15.327   1255.95  <2e-16
# ti(lc_Tree_needleleave_deciduous,month)        15.043 15.782   1212.95  <2e-16
# ti(lc_Tree_broadleaved_evergreen,lc_Shrubs)    14.989 15.022   3675.63  <2e-16
# ti(lc_Tree_broadleaved_deciduous,lc_Shrubs)    12.405 12.584    983.34  <2e-16
# ti(lc_Tree_needleleave_evergreen,lc_Shrubs)    12.898 13.042   5791.69  <2e-16
# ti(lc_Tree_needleleave_deciduous,lc_Shrubs)    13.074 13.167    712.12  <2e-16
# ti(lc_Tree_mixed,lc_Shrubs)                    14.632 14.811   3342.99  <2e-16
# ti(lc_Tree_broadleaved_evergreen,lc_Grassland) 12.865 13.036   9725.92  <2e-16
# ti(lc_Tree_broadleaved_deciduous,lc_Grassland) 12.421 12.682   1580.40  <2e-16
# ti(lc_Tree_needleleave_evergreen,lc_Grassland) 12.914 13.021   4555.41  <2e-16
# ti(lc_Tree_needleleave_deciduous,lc_Grassland)  8.884  9.140    187.50  <2e-16
# ti(lc_Tree_mixed,lc_Grassland)                 12.875 13.002  10858.16  <2e-16
# ti(lc_Tree_broadleaved_evergreen,lc_Urban)     14.994 15.025  14566.50  <2e-16
# ti(lc_Tree_broadleaved_deciduous,lc_Urban)     13.641 13.748    922.29  <2e-16
# ti(lc_Tree_needleleave_evergreen,lc_Urban)     14.894 14.967   5476.49  <2e-16
# ti(lc_Tree_needleleave_deciduous,lc_Urban)     11.900 12.067    796.02  <2e-16
# ti(lc_Tree_mixed,lc_Urban)                     13.054 13.275   2843.42  <2e-16
# ti(lc_Shrubs,lc_Urban)                         14.956 15.004  10179.47  <2e-16
# ti(lc_Grassland,lc_Urban)                      14.975 15.002   4421.62  <2e-16
# ti(lc_Shrubs,solar_radiation)                  14.194 15.004   1521.24  <2e-16
# ti(lc_Shrubs,thermal_radiation)                14.742 15.213   1043.00  <2e-16
# ti(lc_Shrubs,temperature)                      15.116 15.591  11676.80  <2e-16
# ti(lc_Grassland,solar_radiation)               12.703 13.865   1276.58  <2e-16
# ti(lc_Grassland,thermal_radiation)             14.440 15.201   3263.44  <2e-16
# ti(lc_Grassland,temperature)                   15.205 15.711   6739.77  <2e-16
#
# s(lat,lon)                                     ***
# s(year)                                        ***
# s(month)                                       ***
# s(altiMean)                                    ***
# s(altiSD)                                      ***
# s(temperature)                                 ***
# s(dew_temperature)                             ***
# s(potential_evaporation)                       ***
# s(evaporation)                                 ***
# s(solar_radiation)                             ***
# s(thermal_radiation)                           ***
# s(precipitation)                               ***
# s(humidity)                                    ***
# s(Wspeed)                                      ***
# ti(temperature,precipitation)                  ***
# ti(temperature,solar_radiation)                ***
# ti(temperature,thermal_radiation)              ***
# ti(temperature,Wspeed)                         ***
# ti(evaporation,precipitation)                  ***
# ti(potential_evaporation,precipitation)        ***
# s(lc_Cropland)                                 ***
# s(lc_Vegetation_Bare_areas)                    ***
# s(lc_Tree_broadleaved_evergreen)               ***
# s(lc_Tree_broadleaved_deciduous)               ***
# s(lc_Tree_needleleave_evergreen)               ***
# s(lc_Tree_needleleave_deciduous)               ***
# s(lc_Tree_mixed)                               ***
# s(lc_Grassland)                                ***
# s(lc_Shrubs)                                   ***
# s(lc_Urban)                                    ***
# s(lc_Water_and_flooded_areas)                  ***
# ti(lc_Tree_broadleaved_deciduous,month)        ***
# ti(lc_Tree_needleleave_deciduous,month)        ***
# ti(lc_Tree_broadleaved_evergreen,lc_Shrubs)    ***
# ti(lc_Tree_broadleaved_deciduous,lc_Shrubs)    ***
# ti(lc_Tree_needleleave_evergreen,lc_Shrubs)    ***
# ti(lc_Tree_needleleave_deciduous,lc_Shrubs)    ***
# ti(lc_Tree_mixed,lc_Shrubs)                    ***
# ti(lc_Tree_broadleaved_evergreen,lc_Grassland) ***
# ti(lc_Tree_broadleaved_deciduous,lc_Grassland) ***
# ti(lc_Tree_needleleave_evergreen,lc_Grassland) ***
# ti(lc_Tree_needleleave_deciduous,lc_Grassland) ***
# ti(lc_Tree_mixed,lc_Grassland)                 ***
# ti(lc_Tree_broadleaved_evergreen,lc_Urban)     ***
# ti(lc_Tree_broadleaved_deciduous,lc_Urban)     ***
# ti(lc_Tree_needleleave_evergreen,lc_Urban)     ***
# ti(lc_Tree_needleleave_deciduous,lc_Urban)     ***
# ti(lc_Tree_mixed,lc_Urban)                     ***
# ti(lc_Shrubs,lc_Urban)                         ***
# ti(lc_Grassland,lc_Urban)                      ***
# ti(lc_Shrubs,solar_radiation)                  ***
# ti(lc_Shrubs,thermal_radiation)                ***
# ti(lc_Shrubs,temperature)                      ***
# ti(lc_Grassland,solar_radiation)               ***
# ti(lc_Grassland,thermal_radiation)             ***
# ti(lc_Grassland,temperature)                   ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Rank: 749/750
# R-sq.(adj) =   0.41   Deviance explained = 56.8%
# fREML = 9.7091e+05  Scale est. = 1         n = 387187
# Warning message in if (!is.na(df_val)) {:
# "the condition has length > 1 and only the first element will be used"Warning message in if (!is.na(df_val)) {:
# "the condition has length > 1 and only the first element will be used"
# Plot with title "Response vs. Fitted Values"
# [1] "RMSE (train):"
#   rmse_zeros rmse_pos
# 1   1.622997 7.642246
# [1] "RMSE (val):"
#   rmse_zeros rmse_pos
# 1   1.650904 7.666075
# [1] "MAE (train):"
#   mae_zeros  mae_pos
# 1 0.8506541 3.776745
# [1] "MAE (val):"
#   mae_zeros  mae_pos
# 1  0.856199 3.804684
# Plot with title "Validation - Response vs. Fitted Values"

# %% [markdown]
# ## Negative Binomial GAM

# %%
diagnostics.gam(gam.NB, df_val, 'NB')
# Out:
# [1] "AIC:"
# [1] 1079408
#
# Family: Negative Binomial(0.583)
# Link function: log
#
# Formula:
# CNT ~ 1 + s(lat, lon, bs = "sos") + s(year, k = 5) + s(month,
#     k = 3) + s(altiMean) + s(altiSD) + s(temperature) + s(dew_temperature) +
#     s(potential_evaporation) + s(evaporation) + s(solar_radiation) +
#     s(thermal_radiation) + s(precipitation) + s(humidity) + s(Wspeed) +
#     ti(temperature, precipitation) + ti(temperature, solar_radiation) +
#     ti(temperature, thermal_radiation) + ti(temperature, Wspeed) +
#     ti(evaporation, precipitation) + ti(potential_evaporation,
#     precipitation) + s(lc_Cropland) + s(lc_Vegetation_Bare_areas) +
#     s(lc_Tree_broadleaved_evergreen) + s(lc_Tree_broadleaved_deciduous) +
#     s(lc_Tree_needleleave_evergreen) + s(lc_Tree_needleleave_deciduous) +
#     s(lc_Tree_mixed) + s(lc_Grassland) + s(lc_Shrubs) + s(lc_Urban) +
#     s(lc_Water_and_flooded_areas) + ti(lc_Tree_broadleaved_deciduous,
#     month) + ti(lc_Tree_needleleave_deciduous, month) + ti(lc_Tree_broadleaved_evergreen,
#     lc_Shrubs) + ti(lc_Tree_broadleaved_deciduous, lc_Shrubs) +
#     ti(lc_Tree_needleleave_evergreen, lc_Shrubs) + ti(lc_Tree_needleleave_deciduous,
#     lc_Shrubs) + ti(lc_Tree_mixed, lc_Shrubs) + ti(lc_Tree_broadleaved_evergreen,
#     lc_Grassland) + ti(lc_Tree_broadleaved_deciduous, lc_Grassland) +
#     ti(lc_Tree_needleleave_evergreen, lc_Grassland) + ti(lc_Tree_needleleave_deciduous,
#     lc_Grassland) + ti(lc_Tree_mixed, lc_Grassland) + ti(lc_Tree_broadleaved_evergreen,
#     lc_Urban) + ti(lc_Tree_broadleaved_deciduous, lc_Urban) +
#     ti(lc_Tree_needleleave_evergreen, lc_Urban) + ti(lc_Tree_needleleave_deciduous,
#     lc_Urban) + ti(lc_Tree_mixed, lc_Urban) + ti(lc_Shrubs, lc_Urban) +
#     ti(lc_Grassland, lc_Urban) + ti(lc_Shrubs, solar_radiation) +
#     ti(lc_Shrubs, thermal_radiation) + ti(lc_Shrubs, temperature) +
#     ti(lc_Grassland, solar_radiation) + ti(lc_Grassland, thermal_radiation) +
#     ti(lc_Grassland, temperature)
#
# Parametric coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1858.42      78.65   23.63   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Approximate significance of smooth terms:
#                                                   edf Ref.df       F p-value
# s(lat,lon)                                     48.852 49.000 471.629  <2e-16
# s(year)                                         3.745  3.960  63.623  <2e-16
# s(month)                                        1.982  1.999  76.487  <2e-16
# s(altiMean)                                     8.730  8.978 118.627  <2e-16
# s(altiSD)                                       8.737  8.976  49.724  <2e-16
# s(temperature)                                  6.994  7.728   8.187  <2e-16
# s(dew_temperature)                              8.556  8.903  33.015  <2e-16
# s(potential_evaporation)                        7.153  7.855  28.319  <2e-16
# s(evaporation)                                  8.272  8.700  17.249  <2e-16
# s(solar_radiation)                              8.157  8.614  25.315  <2e-16
# s(thermal_radiation)                            8.363  8.761   7.039  <2e-16
# s(precipitation)                                5.623  6.442   3.500  0.0019
# s(humidity)                                     8.514  8.879 248.553  <2e-16
# s(Wspeed)                                       7.240  7.795   7.763  <2e-16
# ti(temperature,precipitation)                  11.988 12.710  66.463  <2e-16
# ti(temperature,solar_radiation)                12.327 13.356  49.329  <2e-16
# ti(temperature,thermal_radiation)              13.481 14.192  12.974  <2e-16
# ti(temperature,Wspeed)                          9.880 11.098  21.178  <2e-16
# ti(evaporation,precipitation)                  10.121 11.474  20.318  <2e-16
# ti(potential_evaporation,precipitation)        10.636 11.289  21.225  <2e-16
# s(lc_Cropland)                                  8.823  8.988 217.196  <2e-16
# s(lc_Vegetation_Bare_areas)                     8.277  8.763  60.483  <2e-16
# s(lc_Tree_broadleaved_evergreen)                8.112  8.553  23.046  <2e-16
# s(lc_Tree_broadleaved_deciduous)                7.365  7.156  61.586  <2e-16
# s(lc_Tree_needleleave_evergreen)                7.663  7.948  60.108  <2e-16
# s(lc_Tree_needleleave_deciduous)                3.200  4.533  18.271  <2e-16
# s(lc_Tree_mixed)                                7.884  8.384  15.329  <2e-16
# s(lc_Grassland)                                 8.933  8.988 104.711  <2e-16
# s(lc_Shrubs)                                    8.366  8.739  50.697  <2e-16
# s(lc_Urban)                                     9.203  9.000 195.532  <2e-16
# s(lc_Water_and_flooded_areas)                   8.860  8.991 179.533  <2e-16
# ti(lc_Tree_broadleaved_deciduous,month)         9.305 10.803  28.384  <2e-16
# ti(lc_Tree_needleleave_deciduous,month)        12.342 14.359  10.822  <2e-16
# ti(lc_Tree_broadleaved_evergreen,lc_Shrubs)    13.782 14.233  21.271  <2e-16
# ti(lc_Tree_broadleaved_deciduous,lc_Shrubs)     5.441  6.010  11.480  <2e-16
# ti(lc_Tree_needleleave_evergreen,lc_Shrubs)    12.047 12.688  95.700  <2e-16
# ti(lc_Tree_needleleave_deciduous,lc_Shrubs)     5.696  6.683   1.445  0.1905
# ti(lc_Tree_mixed,lc_Shrubs)                     9.565 10.019  36.993  <2e-16
# ti(lc_Tree_broadleaved_evergreen,lc_Grassland) 10.384 11.015 146.027  <2e-16
# ti(lc_Tree_broadleaved_deciduous,lc_Grassland) 10.363 10.654  34.375  <2e-16
# ti(lc_Tree_needleleave_evergreen,lc_Grassland) 13.440 13.840  54.558  <2e-16
# ti(lc_Tree_needleleave_deciduous,lc_Grassland)  8.522  9.064   6.531  <2e-16
# ti(lc_Tree_mixed,lc_Grassland)                 10.026 10.457 125.772  <2e-16
# ti(lc_Tree_broadleaved_evergreen,lc_Urban)     12.634 13.011 178.375  <2e-16
# ti(lc_Tree_broadleaved_deciduous,lc_Urban)      5.725  6.879  59.813  <2e-16
# ti(lc_Tree_needleleave_evergreen,lc_Urban)      8.955  9.641  63.476  <2e-16
# ti(lc_Tree_needleleave_deciduous,lc_Urban)      9.536  9.797  21.564  <2e-16
# ti(lc_Tree_mixed,lc_Urban)                     16.057 15.992  71.398  <2e-16
# ti(lc_Shrubs,lc_Urban)                         14.901 15.135  67.375  <2e-16
# ti(lc_Grassland,lc_Urban)                      12.851 13.339  36.201  <2e-16
# ti(lc_Shrubs,solar_radiation)                  12.341 13.842  26.820  <2e-16
# ti(lc_Shrubs,thermal_radiation)                11.687 13.248  18.228  <2e-16
# ti(lc_Shrubs,temperature)                      14.567 15.261 137.875  <2e-16
# ti(lc_Grassland,solar_radiation)                8.001  9.842  32.642  <2e-16
# ti(lc_Grassland,thermal_radiation)             11.256 12.513  43.069  <2e-16
# ti(lc_Grassland,temperature)                   14.342 15.280  90.402  <2e-16
#
# s(lat,lon)                                     ***
# s(year)                                        ***
# s(month)                                       ***
# s(altiMean)                                    ***
# s(altiSD)                                      ***
# s(temperature)                                 ***
# s(dew_temperature)                             ***
# s(potential_evaporation)                       ***
# s(evaporation)                                 ***
# s(solar_radiation)                             ***
# s(thermal_radiation)                           ***
# s(precipitation)                               **
# s(humidity)                                    ***
# s(Wspeed)                                      ***
# ti(temperature,precipitation)                  ***
# ti(temperature,solar_radiation)                ***
# ti(temperature,thermal_radiation)              ***
# ti(temperature,Wspeed)                         ***
# ti(evaporation,precipitation)                  ***
# ti(potential_evaporation,precipitation)        ***
# s(lc_Cropland)                                 ***
# s(lc_Vegetation_Bare_areas)                    ***
# s(lc_Tree_broadleaved_evergreen)               ***
# s(lc_Tree_broadleaved_deciduous)               ***
# s(lc_Tree_needleleave_evergreen)               ***
# s(lc_Tree_needleleave_deciduous)               ***
# s(lc_Tree_mixed)                               ***
# s(lc_Grassland)                                ***
# s(lc_Shrubs)                                   ***
# s(lc_Urban)                                    ***
# s(lc_Water_and_flooded_areas)                  ***
# ti(lc_Tree_broadleaved_deciduous,month)        ***
# ti(lc_Tree_needleleave_deciduous,month)        ***
# ti(lc_Tree_broadleaved_evergreen,lc_Shrubs)    ***
# ti(lc_Tree_broadleaved_deciduous,lc_Shrubs)    ***
# ti(lc_Tree_needleleave_evergreen,lc_Shrubs)    ***
# ti(lc_Tree_needleleave_deciduous,lc_Shrubs)
# ti(lc_Tree_mixed,lc_Shrubs)                    ***
# ti(lc_Tree_broadleaved_evergreen,lc_Grassland) ***
# ti(lc_Tree_broadleaved_deciduous,lc_Grassland) ***
# ti(lc_Tree_needleleave_evergreen,lc_Grassland) ***
# ti(lc_Tree_needleleave_deciduous,lc_Grassland) ***
# ti(lc_Tree_mixed,lc_Grassland)                 ***
# ti(lc_Tree_broadleaved_evergreen,lc_Urban)     ***
# ti(lc_Tree_broadleaved_deciduous,lc_Urban)     ***
# ti(lc_Tree_needleleave_evergreen,lc_Urban)     ***
# ti(lc_Tree_needleleave_deciduous,lc_Urban)     ***
# ti(lc_Tree_mixed,lc_Urban)                     ***
# ti(lc_Shrubs,lc_Urban)                         ***
# ti(lc_Grassland,lc_Urban)                      ***
# ti(lc_Shrubs,solar_radiation)                  ***
# ti(lc_Shrubs,thermal_radiation)                ***
# ti(lc_Shrubs,temperature)                      ***
# ti(lc_Grassland,solar_radiation)               ***
# ti(lc_Grassland,thermal_radiation)             ***
# ti(lc_Grassland,temperature)                   ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# R-sq.(adj) =  0.217   Deviance explained = 52.1%
# fREML = 5.0893e+05  Scale est. = 1         n = 387187
# Warning message in if (!is.na(df_val)) {:
# "the condition has length > 1 and only the first element will be used"Warning message in if (!is.na(df_val)) {:
# "the condition has length > 1 and only the first element will be used"
# Plot with title "Response vs. Fitted Values"
# [1] "RMSE (train):"
#   rmse_zeros rmse_pos
# 1   1.741362 8.856092
# [1] "RMSE (val):"
#   rmse_zeros rmse_pos
# 1   1.837962 8.890124
# [1] "MAE (train):"
#   mae_zeros  mae_pos
# 1 0.8128571 4.310197
# [1] "MAE (val):"
#   mae_zeros  mae_pos
# 1 0.8215118 4.312746
# Plot with title "Validation - Response vs. Fitted Values"

# %% [markdown]
# ## Quasipoisson GAM

# %%
diagnostics.gam(gam.qp, df_val, 'qp')
# Out:
# [1] "AIC:"
# [1] NA
#
# Family: quasipoisson
# Link function: log
#
# Formula:
# CNT ~ 1 + s(lat, lon, bs = "sos") + s(year, k = 5) + s(month,
#     k = 3) + s(altiMean) + s(altiSD) + s(temperature) + s(dew_temperature) +
#     s(potential_evaporation) + s(evaporation) + s(solar_radiation) +
#     s(thermal_radiation) + s(precipitation) + s(humidity) + s(Wspeed) +
#     ti(temperature, precipitation) + ti(temperature, solar_radiation) +
#     ti(temperature, thermal_radiation) + ti(temperature, Wspeed) +
#     ti(evaporation, precipitation) + ti(potential_evaporation,
#     precipitation) + s(lc_Cropland) + s(lc_Vegetation_Bare_areas) +
#     s(lc_Tree_broadleaved_evergreen) + s(lc_Tree_broadleaved_deciduous) +
#     s(lc_Tree_needleleave_evergreen) + s(lc_Tree_needleleave_deciduous) +
#     s(lc_Tree_mixed) + s(lc_Grassland) + s(lc_Shrubs) + s(lc_Urban) +
#     s(lc_Water_and_flooded_areas) + ti(lc_Tree_broadleaved_deciduous,
#     month) + ti(lc_Tree_needleleave_deciduous, month) + ti(lc_Tree_broadleaved_evergreen,
#     lc_Shrubs) + ti(lc_Tree_broadleaved_deciduous, lc_Shrubs) +
#     ti(lc_Tree_needleleave_evergreen, lc_Shrubs) + ti(lc_Tree_needleleave_deciduous,
#     lc_Shrubs) + ti(lc_Tree_mixed, lc_Shrubs) + ti(lc_Tree_broadleaved_evergreen,
#     lc_Grassland) + ti(lc_Tree_broadleaved_deciduous, lc_Grassland) +
#     ti(lc_Tree_needleleave_evergreen, lc_Grassland) + ti(lc_Tree_needleleave_deciduous,
#     lc_Grassland) + ti(lc_Tree_mixed, lc_Grassland) + ti(lc_Tree_broadleaved_evergreen,
#     lc_Urban) + ti(lc_Tree_broadleaved_deciduous, lc_Urban) +
#     ti(lc_Tree_needleleave_evergreen, lc_Urban) + ti(lc_Tree_needleleave_deciduous,
#     lc_Urban) + ti(lc_Tree_mixed, lc_Urban) + ti(lc_Shrubs, lc_Urban) +
#     ti(lc_Grassland, lc_Urban) + ti(lc_Shrubs, solar_radiation) +
#     ti(lc_Shrubs, thermal_radiation) + ti(lc_Shrubs, temperature) +
#     ti(lc_Grassland, solar_radiation) + ti(lc_Grassland, thermal_radiation) +
#     ti(lc_Grassland, temperature)
#
# Parametric coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1191.97      60.86   19.59   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Approximate significance of smooth terms:
#                                                   edf Ref.df       F  p-value
# s(lat,lon)                                     48.817 49.000 366.875  < 2e-16
# s(year)                                         3.879  3.991 127.196  < 2e-16
# s(month)                                        1.985  1.999  54.645  < 2e-16
# s(altiMean)                                     8.684  8.969  57.297  < 2e-16
# s(altiSD)                                       8.877  8.994  59.010  < 2e-16
# s(temperature)                                  7.388  7.966   8.883  < 2e-16
# s(dew_temperature)                              8.598  8.901  59.667  < 2e-16
# s(potential_evaporation)                        6.893  7.698  14.828  < 2e-16
# s(evaporation)                                  8.598  8.879  19.164  < 2e-16
# s(solar_radiation)                              7.272  7.792  25.021  < 2e-16
# s(thermal_radiation)                            8.324  8.731  12.439  < 2e-16
# s(precipitation)                                4.349  5.083   3.573 0.004853
# s(humidity)                                     8.602  8.923 196.811  < 2e-16
# s(Wspeed)                                       7.052  7.563   3.996 0.002896
# ti(temperature,precipitation)                  11.175 11.953  67.417  < 2e-16
# ti(temperature,solar_radiation)                10.402 11.572  22.458  < 2e-16
# ti(temperature,thermal_radiation)              13.046 13.785  22.452  < 2e-16
# ti(temperature,Wspeed)                          9.392 10.424  28.985  < 2e-16
# ti(evaporation,precipitation)                   8.130  9.492   8.344  < 2e-16
# ti(potential_evaporation,precipitation)        10.856 11.487  19.874  < 2e-16
# s(lc_Cropland)                                  8.825  8.987 158.849  < 2e-16
# s(lc_Vegetation_Bare_areas)                     8.330  8.757  75.965  < 2e-16
# s(lc_Tree_broadleaved_evergreen)                8.915  8.987  47.235  < 2e-16
# s(lc_Tree_broadleaved_deciduous)                6.524  6.918  76.582  < 2e-16
# s(lc_Tree_needleleave_evergreen)                6.980  7.309  25.308  < 2e-16
# s(lc_Tree_needleleave_deciduous)                3.773  4.793   8.452  < 2e-16
# s(lc_Tree_mixed)                                8.606  8.773  21.530  < 2e-16
# s(lc_Grassland)                                 8.911  8.989  73.096  < 2e-16
# s(lc_Shrubs)                                    8.788  8.959  72.018  < 2e-16
# s(lc_Urban)                                     8.955  8.991 202.630  < 2e-16
# s(lc_Water_and_flooded_areas)                   8.789  8.979 130.282  < 2e-16
# ti(lc_Tree_broadleaved_deciduous,month)         6.821  8.094  26.903  < 2e-16
# ti(lc_Tree_needleleave_deciduous,month)        11.823 13.690  17.514  < 2e-16
# ti(lc_Tree_broadleaved_evergreen,lc_Shrubs)    14.516 14.833  35.609  < 2e-16
# ti(lc_Tree_broadleaved_deciduous,lc_Shrubs)     6.697  7.232   5.952  < 2e-16
# ti(lc_Tree_needleleave_evergreen,lc_Shrubs)    11.527 12.236  89.880  < 2e-16
# ti(lc_Tree_needleleave_deciduous,lc_Shrubs)     7.252  8.038   3.194 0.000971
# ti(lc_Tree_mixed,lc_Shrubs)                     8.575  9.253  49.435  < 2e-16
# ti(lc_Tree_broadleaved_evergreen,lc_Grassland) 12.169 12.660 133.548  < 2e-16
# ti(lc_Tree_broadleaved_deciduous,lc_Grassland)  8.249  8.601  33.318  < 2e-16
# ti(lc_Tree_needleleave_evergreen,lc_Grassland) 13.242 13.638  56.147  < 2e-16
# ti(lc_Tree_needleleave_deciduous,lc_Grassland)  3.792  4.517   4.545 0.000826
# ti(lc_Tree_mixed,lc_Grassland)                 12.111 12.725 148.141  < 2e-16
# ti(lc_Tree_broadleaved_evergreen,lc_Urban)     12.975 13.144 182.589  < 2e-16
# ti(lc_Tree_broadleaved_deciduous,lc_Urban)     12.941 12.998  60.652  < 2e-16
# ti(lc_Tree_needleleave_evergreen,lc_Urban)     10.302 10.659  79.242  < 2e-16
# ti(lc_Tree_needleleave_deciduous,lc_Urban)      3.072  3.330  28.303  < 2e-16
# ti(lc_Tree_mixed,lc_Urban)                     11.150 11.643  32.673  < 2e-16
# ti(lc_Shrubs,lc_Urban)                         14.922 15.064 118.096  < 2e-16
# ti(lc_Grassland,lc_Urban)                      13.125 13.578  47.089  < 2e-16
# ti(lc_Shrubs,solar_radiation)                  11.472 12.840  22.358  < 2e-16
# ti(lc_Shrubs,thermal_radiation)                10.413 11.702  11.404  < 2e-16
# ti(lc_Shrubs,temperature)                      13.873 14.708 134.073  < 2e-16
# ti(lc_Grassland,solar_radiation)                8.445 10.106  19.413  < 2e-16
# ti(lc_Grassland,thermal_radiation)             11.570 12.794  44.118  < 2e-16
# ti(lc_Grassland,temperature)                   13.613 14.643  79.230  < 2e-16
#
# s(lat,lon)                                     ***
# s(year)                                        ***
# s(month)                                       ***
# s(altiMean)                                    ***
# s(altiSD)                                      ***
# s(temperature)                                 ***
# s(dew_temperature)                             ***
# s(potential_evaporation)                       ***
# s(evaporation)                                 ***
# s(solar_radiation)                             ***
# s(thermal_radiation)                           ***
# s(precipitation)                               **
# s(humidity)                                    ***
# s(Wspeed)                                      **
# ti(temperature,precipitation)                  ***
# ti(temperature,solar_radiation)                ***
# ti(temperature,thermal_radiation)              ***
# ti(temperature,Wspeed)                         ***
# ti(evaporation,precipitation)                  ***
# ti(potential_evaporation,precipitation)        ***
# s(lc_Cropland)                                 ***
# s(lc_Vegetation_Bare_areas)                    ***
# s(lc_Tree_broadleaved_evergreen)               ***
# s(lc_Tree_broadleaved_deciduous)               ***
# s(lc_Tree_needleleave_evergreen)               ***
# s(lc_Tree_needleleave_deciduous)               ***
# s(lc_Tree_mixed)                               ***
# s(lc_Grassland)                                ***
# s(lc_Shrubs)                                   ***
# s(lc_Urban)                                    ***
# s(lc_Water_and_flooded_areas)                  ***
# ti(lc_Tree_broadleaved_deciduous,month)        ***
# ti(lc_Tree_needleleave_deciduous,month)        ***
# ti(lc_Tree_broadleaved_evergreen,lc_Shrubs)    ***
# ti(lc_Tree_broadleaved_deciduous,lc_Shrubs)    ***
# ti(lc_Tree_needleleave_evergreen,lc_Shrubs)    ***
# ti(lc_Tree_needleleave_deciduous,lc_Shrubs)    ***
# ti(lc_Tree_mixed,lc_Shrubs)                    ***
# ti(lc_Tree_broadleaved_evergreen,lc_Grassland) ***
# ti(lc_Tree_broadleaved_deciduous,lc_Grassland) ***
# ti(lc_Tree_needleleave_evergreen,lc_Grassland) ***
# ti(lc_Tree_needleleave_deciduous,lc_Grassland) ***
# ti(lc_Tree_mixed,lc_Grassland)                 ***
# ti(lc_Tree_broadleaved_evergreen,lc_Urban)     ***
# ti(lc_Tree_broadleaved_deciduous,lc_Urban)     ***
# ti(lc_Tree_needleleave_evergreen,lc_Urban)     ***
# ti(lc_Tree_needleleave_deciduous,lc_Urban)     ***
# ti(lc_Tree_mixed,lc_Urban)                     ***
# ti(lc_Shrubs,lc_Urban)                         ***
# ti(lc_Grassland,lc_Urban)                      ***
# ti(lc_Shrubs,solar_radiation)                  ***
# ti(lc_Shrubs,thermal_radiation)                ***
# ti(lc_Shrubs,temperature)                      ***
# ti(lc_Grassland,solar_radiation)               ***
# ti(lc_Grassland,thermal_radiation)             ***
# ti(lc_Grassland,temperature)                   ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# R-sq.(adj) =  0.406   Deviance explained = 56.6%
# fREML = 8.064e+05  Scale est. = 5.9552    n = 387187
# Warning message in if (!is.na(df_val)) {:
# "the condition has length > 1 and only the first element will be used"Warning message in if (!is.na(df_val)) {:
# "the condition has length > 1 and only the first element will be used"
# Plot with title "Response vs. Fitted Values"
# [1] "RMSE (train):"
#   rmse_zeros rmse_pos
# 1   1.625331 7.669891
# [1] "RMSE (val):"
#   rmse_zeros rmse_pos
# 1   1.655154  7.68438
# [1] "MAE (train):"
#   mae_zeros  mae_pos
# 1 0.8556328 3.783458
# [1] "MAE (val):"
#   mae_zeros  mae_pos
# 1  0.860349 3.809115
# Plot with title "Validation - Response vs. Fitted Values"

# %% [markdown]
# ## Quasipoisson GAM - full model

# %%
diagnostics.gam(gam.qp.full, NA, 'qp_full')
# Out:
# [1] "AIC:"
# [1] NA
#
# Family: quasipoisson
# Link function: log
#
# Formula:
# CNT ~ 1 + s(lat, lon, bs = "sos") + s(year, k = 5) + s(month,
#     k = 3) + s(altiMean) + s(altiSD) + s(temperature) + s(dew_temperature) +
#     s(potential_evaporation) + s(evaporation) + s(solar_radiation) +
#     s(thermal_radiation) + s(precipitation) + s(humidity) + s(Wspeed) +
#     ti(temperature, precipitation) + ti(temperature, solar_radiation) +
#     ti(temperature, thermal_radiation) + ti(temperature, Wspeed) +
#     ti(evaporation, precipitation) + ti(potential_evaporation,
#     precipitation) + s(lc_Cropland) + s(lc_Vegetation_Bare_areas) +
#     s(lc_Tree_broadleaved_evergreen) + s(lc_Tree_broadleaved_deciduous) +
#     s(lc_Tree_needleleave_evergreen) + s(lc_Tree_needleleave_deciduous) +
#     s(lc_Tree_mixed) + s(lc_Grassland) + s(lc_Shrubs) + s(lc_Urban) +
#     s(lc_Water_and_flooded_areas) + ti(lc_Tree_broadleaved_deciduous,
#     month) + ti(lc_Tree_needleleave_deciduous, month) + ti(lc_Tree_broadleaved_evergreen,
#     lc_Shrubs) + ti(lc_Tree_broadleaved_deciduous, lc_Shrubs) +
#     ti(lc_Tree_needleleave_evergreen, lc_Shrubs) + ti(lc_Tree_needleleave_deciduous,
#     lc_Shrubs) + ti(lc_Tree_mixed, lc_Shrubs) + ti(lc_Tree_broadleaved_evergreen,
#     lc_Grassland) + ti(lc_Tree_broadleaved_deciduous, lc_Grassland) +
#     ti(lc_Tree_needleleave_evergreen, lc_Grassland) + ti(lc_Tree_needleleave_deciduous,
#     lc_Grassland) + ti(lc_Tree_mixed, lc_Grassland) + ti(lc_Tree_broadleaved_evergreen,
#     lc_Urban) + ti(lc_Tree_broadleaved_deciduous, lc_Urban) +
#     ti(lc_Tree_needleleave_evergreen, lc_Urban) + ti(lc_Tree_needleleave_deciduous,
#     lc_Urban) + ti(lc_Tree_mixed, lc_Urban) + ti(lc_Shrubs, lc_Urban) +
#     ti(lc_Grassland, lc_Urban) + ti(lc_Shrubs, solar_radiation) +
#     ti(lc_Shrubs, thermal_radiation) + ti(lc_Shrubs, temperature) +
#     ti(lc_Grassland, solar_radiation) + ti(lc_Grassland, thermal_radiation) +
#     ti(lc_Grassland, temperature)
#
# Parametric coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1170.64      54.53   21.47   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Approximate significance of smooth terms:
#                                                   edf Ref.df       F  p-value
# s(lat,lon)                                     48.847 49.000 438.734  < 2e-16
# s(year)                                         3.896  3.993 150.792  < 2e-16
# s(month)                                        1.983  1.999  59.302  < 2e-16
# s(altiMean)                                     8.731  8.977  67.081  < 2e-16
# s(altiSD)                                       8.899  8.996  73.464  < 2e-16
# s(temperature)                                  7.907  8.368  13.034  < 2e-16
# s(dew_temperature)                              8.569  8.887  64.060  < 2e-16
# s(potential_evaporation)                        7.221  7.908  17.654  < 2e-16
# s(evaporation)                                  8.527  8.837  22.320  < 2e-16
# s(solar_radiation)                              7.278  7.795  27.331  < 2e-16
# s(thermal_radiation)                            8.430  8.781  13.374  < 2e-16
# s(precipitation)                                3.886  4.591   4.514 0.000556
# s(humidity)                                     8.592  8.920 236.591  < 2e-16
# s(Wspeed)                                       3.258  3.949   1.461 0.169142
# ti(temperature,precipitation)                  11.526 12.256  78.349  < 2e-16
# ti(temperature,solar_radiation)                10.790 11.945  25.339  < 2e-16
# ti(temperature,thermal_radiation)              13.338 14.028  26.524  < 2e-16
# ti(temperature,Wspeed)                          9.715 10.797  32.270  < 2e-16
# ti(evaporation,precipitation)                   9.152 10.366  12.611  < 2e-16
# ti(potential_evaporation,precipitation)        10.996 11.621  22.124  < 2e-16
# s(lc_Cropland)                                  8.840  8.989 182.080  < 2e-16
# s(lc_Vegetation_Bare_areas)                     8.336  8.760  95.066  < 2e-16
# s(lc_Tree_broadleaved_evergreen)                8.925  8.991  50.709  < 2e-16
# s(lc_Tree_broadleaved_deciduous)                6.668  6.964  49.560  < 2e-16
# s(lc_Tree_needleleave_evergreen)                6.987  7.320  33.508  < 2e-16
# s(lc_Tree_needleleave_deciduous)                4.317  5.372  16.170  < 2e-16
# s(lc_Tree_mixed)                                8.356  8.617  28.968  < 2e-16
# s(lc_Grassland)                                 8.925  8.992  81.224  < 2e-16
# s(lc_Shrubs)                                    8.810  8.965  77.709  < 2e-16
# s(lc_Urban)                                     8.994  9.000 253.636  < 2e-16
# s(lc_Water_and_flooded_areas)                   8.825  8.985 159.629  < 2e-16
# ti(lc_Tree_broadleaved_deciduous,month)         7.611  8.969  29.838  < 2e-16
# ti(lc_Tree_needleleave_deciduous,month)        12.029 13.843  19.960  < 2e-16
# ti(lc_Tree_broadleaved_evergreen,lc_Shrubs)    14.519 14.819  39.166  < 2e-16
# ti(lc_Tree_broadleaved_deciduous,lc_Shrubs)     6.841  7.336   8.654  < 2e-16
# ti(lc_Tree_needleleave_evergreen,lc_Shrubs)    11.926 12.549 102.053  < 2e-16
# ti(lc_Tree_needleleave_deciduous,lc_Shrubs)     7.522  8.267   3.209 0.000684
# ti(lc_Tree_mixed,lc_Shrubs)                     9.418  9.929  57.567  < 2e-16
# ti(lc_Tree_broadleaved_evergreen,lc_Grassland) 12.309 12.773 167.897  < 2e-16
# ti(lc_Tree_broadleaved_deciduous,lc_Grassland) 11.750 12.039  42.985  < 2e-16
# ti(lc_Tree_needleleave_evergreen,lc_Grassland) 13.360 13.729  68.365  < 2e-16
# ti(lc_Tree_needleleave_deciduous,lc_Grassland)  2.899  3.590   6.400 0.000406
# ti(lc_Tree_mixed,lc_Grassland)                 12.290 12.838 163.141  < 2e-16
# ti(lc_Tree_broadleaved_evergreen,lc_Urban)     13.004 13.167 227.518  < 2e-16
# ti(lc_Tree_broadleaved_deciduous,lc_Urban)     10.936 11.216  81.364  < 2e-16
# ti(lc_Tree_needleleave_evergreen,lc_Urban)     10.601 10.918  88.510  < 2e-16
# ti(lc_Tree_needleleave_deciduous,lc_Urban)      4.136  4.230  41.687  < 2e-16
# ti(lc_Tree_mixed,lc_Urban)                     13.208 13.764  47.996  < 2e-16
# ti(lc_Shrubs,lc_Urban)                         14.957 15.079 146.153  < 2e-16
# ti(lc_Grassland,lc_Urban)                      13.173 13.613  63.641  < 2e-16
# ti(lc_Shrubs,solar_radiation)                  12.123 13.398  27.699  < 2e-16
# ti(lc_Shrubs,thermal_radiation)                10.112 11.383  12.085  < 2e-16
# ti(lc_Shrubs,temperature)                      13.935 14.747 158.595  < 2e-16
# ti(lc_Grassland,solar_radiation)                9.105 10.726  22.794  < 2e-16
# ti(lc_Grassland,thermal_radiation)             11.814 12.986  53.721  < 2e-16
# ti(lc_Grassland,temperature)                   13.783 14.764  93.839  < 2e-16
#
# s(lat,lon)                                     ***
# s(year)                                        ***
# s(month)                                       ***
# s(altiMean)                                    ***
# s(altiSD)                                      ***
# s(temperature)                                 ***
# s(dew_temperature)                             ***
# s(potential_evaporation)                       ***
# s(evaporation)                                 ***
# s(solar_radiation)                             ***
# s(thermal_radiation)                           ***
# s(precipitation)                               ***
# s(humidity)                                    ***
# s(Wspeed)
# ti(temperature,precipitation)                  ***
# ti(temperature,solar_radiation)                ***
# ti(temperature,thermal_radiation)              ***
# ti(temperature,Wspeed)                         ***
# ti(evaporation,precipitation)                  ***
# ti(potential_evaporation,precipitation)        ***
# s(lc_Cropland)                                 ***
# s(lc_Vegetation_Bare_areas)                    ***
# s(lc_Tree_broadleaved_evergreen)               ***
# s(lc_Tree_broadleaved_deciduous)               ***
# s(lc_Tree_needleleave_evergreen)               ***
# s(lc_Tree_needleleave_deciduous)               ***
# s(lc_Tree_mixed)                               ***
# s(lc_Grassland)                                ***
# s(lc_Shrubs)                                   ***
# s(lc_Urban)                                    ***
# s(lc_Water_and_flooded_areas)                  ***
# ti(lc_Tree_broadleaved_deciduous,month)        ***
# ti(lc_Tree_needleleave_deciduous,month)        ***
# ti(lc_Tree_broadleaved_evergreen,lc_Shrubs)    ***
# ti(lc_Tree_broadleaved_deciduous,lc_Shrubs)    ***
# ti(lc_Tree_needleleave_evergreen,lc_Shrubs)    ***
# ti(lc_Tree_needleleave_deciduous,lc_Shrubs)    ***
# ti(lc_Tree_mixed,lc_Shrubs)                    ***
# ti(lc_Tree_broadleaved_evergreen,lc_Grassland) ***
# ti(lc_Tree_broadleaved_deciduous,lc_Grassland) ***
# ti(lc_Tree_needleleave_evergreen,lc_Grassland) ***
# ti(lc_Tree_needleleave_deciduous,lc_Grassland) ***
# ti(lc_Tree_mixed,lc_Grassland)                 ***
# ti(lc_Tree_broadleaved_evergreen,lc_Urban)     ***
# ti(lc_Tree_broadleaved_deciduous,lc_Urban)     ***
# ti(lc_Tree_needleleave_evergreen,lc_Urban)     ***
# ti(lc_Tree_needleleave_deciduous,lc_Urban)     ***
# ti(lc_Tree_mixed,lc_Urban)                     ***
# ti(lc_Shrubs,lc_Urban)                         ***
# ti(lc_Grassland,lc_Urban)                      ***
# ti(lc_Shrubs,solar_radiation)                  ***
# ti(lc_Shrubs,thermal_radiation)                ***
# ti(lc_Shrubs,temperature)                      ***
# ti(lc_Grassland,solar_radiation)               ***
# ti(lc_Grassland,thermal_radiation)             ***
# ti(lc_Grassland,temperature)                   ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# R-sq.(adj) =  0.408   Deviance explained = 56.7%
# fREML = 1.0122e+06  Scale est. = 6.1899    n = 483983
# Plot with title "Response vs. Fitted Values"

# %% [markdown]
# ### Plots (individually)

# %%
p <- plot(gam.qp.full, scale=0, pers=FALSE, se=TRUE, scheme=0)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ### Plots (more plots on one page)

# %%
plot(gam.qp.full, scale=0, scheme=1, pers=FALSE, se=TRUE, pages=5, family="B")
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# Location smoothing separately

# %%
plot(gam.qp.full, scale=0, pers=FALSE, se=TRUE, scheme=0, select=1, theta=50)
# Out:
# plot without title

# %% [markdown]
# ### Show the same plots using ggplot2

# %%
# extract data from plots
df_smooths <- data.frame(x=double(),
                         fit=double(),
                         se=double(),
                         xlab=character(),
                         ylab=character())

df_ti <- data.frame(x=double(),
                    y=double(),
                    fit=double(),
                    se=double(),
                    xlab=character(),
                    ylab=character(),
                    main=character())

z <- 1.96
for (i in 1:length(p)){
  if (i == 1){
    df_la_lon <- data.frame(x=p[[i]]$lo,
                            y=p[[i]]$la,
                            fit=p[[i]]$fit,
                            xlab="latitude",
                            ylab="longitude",
                            main="position")
  } else if ((i > 1 & i < 15) | (i > 20 & i < 32)){
    d <- data.frame(x=p[[i]]$x,
                    fit=p[[i]]$fit,
                    se=p[[i]]$se,
                    xlab=p[[i]]$xlab,
                    ylab=p[[i]]$ylab)
    
    df_smooths <- rbind(df_smooths, d)
  } else {
    d <- data.frame(x=rep(p[[i]]$x, 40),
                    y=as.vector(t(matrix(rep(p[[i]]$y, 40), nrow=40))),
                    fit=p[[i]]$fit,
                    se=p[[i]]$se,
                    xlab=p[[i]]$xlab,
                    ylab=p[[i]]$ylab,
                    main=p[[i]]$main)

    df_ti <- rbind(df_ti, d)
  }
}
df_ti <- df_ti %>% mutate(main=gsub(',', ', ', main))

# %% [markdown]
# Plot individual smooths of main effects

# %%
df_smooths %>% 
    ggplot() + 
    geom_line(aes(x=x, y=fit), colour="black") + 
    geom_ribbon(aes(x=x, ymin=fit-z*se, ymax=fit+z*se), alpha=0.25) + 
    facet_wrap(~ylab, scales="free", ncol=4) + 
    theme_minimal() + xlab("variable, edf") + ylab("s(variable) +/- 1.96 SE") + 
    theme(aspect.ratio = 1/2, text=element_text(size=6)) #+ 
#     guides(x = guide_axis(angle = 90))
# ggsave('Figures/smooths.pdf')
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %% [markdown]
# Contour plots for tensor product smooth interactions

# %%
df_ti %>% 
    ggplot(aes(x, y)) + 
    geom_contour_filled(aes(z=fit), colour="black", na.rm=TRUE, size=0.25) + 
    geom_contour(aes(z=fit+z*se), colour="red", na.rm=TRUE, size=0.25) + 
    geom_contour(aes(z=fit-z*se), colour="blue", na.rm=TRUE, size=0.25) + 
    facet_wrap(~main, scales="free", ncol=4, labeller = labeller(main=label_wrap_gen(10))) + 
    theme_minimal() + ylab("var2") + xlab("var1") + 
    theme(aspect.ratio = 1/2, text=element_text(size=4))
# ggsave('Figures/Interactions.pdf')
# Out:
# Warning message:
# "stat_contour(): Zero contours were generated"Warning message in min(x):
# "no non-missing arguments to min; returning Inf"Warning message in max(x):
# "no non-missing arguments to max; returning -Inf"Warning message:
# "stat_contour(): Zero contours were generated"Warning message in min(x):
# "no non-missing arguments to min; returning Inf"Warning message in max(x):
# "no non-missing arguments to max; returning -Inf"Saving 6.67 x 6.67 in image
# Warning message:
# "stat_contour(): Zero contours were generated"Warning message in min(x):
# "no non-missing arguments to min; returning Inf"Warning message in max(x):
# "no non-missing arguments to max; returning -Inf"Warning message:
# "stat_contour(): Zero contours were generated"Warning message in min(x):
# "no non-missing arguments to min; returning Inf"Warning message in max(x):
# "no non-missing arguments to max; returning -Inf"
# plot without title
